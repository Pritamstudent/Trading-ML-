# %%
import pandas as pd

# %%
df = pd.read_csv("buy_and_hold.csv")
df.head()
# Out:
#                   Unnamed: 0                period_open  \
# 0  2008-01-02 21:00:00+00:00  2008-01-02 14:31:00+00:00
# 1  2008-01-03 21:00:00+00:00  2008-01-03 14:31:00+00:00
# 2  2008-01-04 21:00:00+00:00  2008-01-04 14:31:00+00:00
# 3  2008-01-07 21:00:00+00:00  2008-01-07 14:31:00+00:00
# 4  2008-01-08 21:00:00+00:00  2008-01-08 14:31:00+00:00
#
#                 period_close  portfolio_value  longs_count  shorts_count  \
# 0  2008-01-02 21:00:00+00:00     1.000000e+07            0             0
# 1  2008-01-03 21:00:00+00:00     9.999970e+06            1             0
# 2  2008-01-04 21:00:00+00:00     9.995506e+06            1             0
# 3  2008-01-07 21:00:00+00:00     9.994783e+06            1             0
# 4  2008-01-08 21:00:00+00:00     9.992866e+06            1             0
#
#    long_value  short_value  long_exposure        pnl  ...  alpha  beta  \
# 0         0.0          0.0            0.0     0.0000  ...    NaN   NaN
# ...

# %%
df.tail()
# Out:
#                      Unnamed: 0                period_open  \
# 2513  2017-12-22 21:00:00+00:00  2017-12-22 14:31:00+00:00
# 2514  2017-12-26 21:00:00+00:00  2017-12-26 14:31:00+00:00
# 2515  2017-12-27 21:00:00+00:00  2017-12-27 14:31:00+00:00
# 2516  2017-12-28 21:00:00+00:00  2017-12-28 14:31:00+00:00
# 2517  2017-12-29 21:00:00+00:00  2017-12-29 14:31:00+00:00
#
#                    period_close  portfolio_value  longs_count  shorts_count  \
# 2513  2017-12-22 21:00:00+00:00     1.030901e+07            1             0
# 2514  2017-12-26 21:00:00+00:00     1.029969e+07            1             0
# 2515  2017-12-27 21:00:00+00:00     1.029975e+07            1             0
# 2516  2017-12-28 21:00:00+00:00     1.030076e+07            1             0
# 2517  2017-12-29 21:00:00+00:00     1.029687e+07            1             0
#
#       long_value  short_value  long_exposure     pnl  ...  alpha  beta  \
# 2513    367521.0          0.0       367521.0     0.0  ...    NaN   NaN
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'period_open', 'period_close', 'portfolio_value',
#        'longs_count', 'shorts_count', 'long_value', 'short_value',
#        'long_exposure', 'pnl', 'short_exposure', 'capital_used', 'orders',
#        'transactions', 'gross_leverage', 'positions', 'net_leverage',
#        'starting_exposure', 'returns', 'ending_exposure', 'starting_value',
#        'ending_value', 'starting_cash', 'ending_cash', 'AAPI',
#        'algo_volatility', 'benchmark_period_return', 'benchmark_volatility',
#        'algorithm_period_return', 'alpha', 'beta', 'sharpe', 'sortino',
#        'max_drawdown', 'max_leverage', 'excess_return',
#        'treasury_period_return', 'trading_days', 'period_label'],
#       dtype='object')

# %%
df['timestamp'] = df['Unnamed: 0']

# %%
df.head()
# Out:
#                   Unnamed: 0                period_open  \
# 0  2008-01-02 21:00:00+00:00  2008-01-02 14:31:00+00:00
# 1  2008-01-03 21:00:00+00:00  2008-01-03 14:31:00+00:00
# 2  2008-01-04 21:00:00+00:00  2008-01-04 14:31:00+00:00
# 3  2008-01-07 21:00:00+00:00  2008-01-07 14:31:00+00:00
# 4  2008-01-08 21:00:00+00:00  2008-01-08 14:31:00+00:00
#
#                 period_close  portfolio_value  longs_count  shorts_count  \
# 0  2008-01-02 21:00:00+00:00     1.000000e+07            0             0
# 1  2008-01-03 21:00:00+00:00     9.999970e+06            1             0
# 2  2008-01-04 21:00:00+00:00     9.995506e+06            1             0
# 3  2008-01-07 21:00:00+00:00     9.994783e+06            1             0
# 4  2008-01-08 21:00:00+00:00     9.992866e+06            1             0
#
#    long_value  short_value  long_exposure        pnl  ...  beta     sharpe  \
# 0         0.0          0.0            0.0     0.0000  ...   NaN        NaN
# ...

# %%
df.index = df.timestamp

# %%
df.head()
# Out:
#                                           Unnamed: 0  \
# timestamp
# 2008-01-02 21:00:00+00:00  2008-01-02 21:00:00+00:00
# 2008-01-03 21:00:00+00:00  2008-01-03 21:00:00+00:00
# 2008-01-04 21:00:00+00:00  2008-01-04 21:00:00+00:00
# 2008-01-07 21:00:00+00:00  2008-01-07 21:00:00+00:00
# 2008-01-08 21:00:00+00:00  2008-01-08 21:00:00+00:00
#
#                                          period_open  \
# timestamp
# 2008-01-02 21:00:00+00:00  2008-01-02 14:31:00+00:00
# 2008-01-03 21:00:00+00:00  2008-01-03 14:31:00+00:00
# 2008-01-04 21:00:00+00:00  2008-01-04 14:31:00+00:00
# 2008-01-07 21:00:00+00:00  2008-01-07 14:31:00+00:00
# 2008-01-08 21:00:00+00:00  2008-01-08 14:31:00+00:00
#
#                                         period_close  portfolio_value  \
# timestamp
# 2008-01-02 21:00:00+00:00  2008-01-02 21:00:00+00:00     1.000000e+07
# 2008-01-03 21:00:00+00:00  2008-01-03 21:00:00+00:00     9.999970e+06
# 2008-01-04 21:00:00+00:00  2008-01-04 21:00:00+00:00     9.995506e+06
# ...

# %%
df.tail()
# Out:
#                                           Unnamed: 0  \
# timestamp
# 2017-12-22 21:00:00+00:00  2017-12-22 21:00:00+00:00
# 2017-12-26 21:00:00+00:00  2017-12-26 21:00:00+00:00
# 2017-12-27 21:00:00+00:00  2017-12-27 21:00:00+00:00
# 2017-12-28 21:00:00+00:00  2017-12-28 21:00:00+00:00
# 2017-12-29 21:00:00+00:00  2017-12-29 21:00:00+00:00
#
#                                          period_open  \
# timestamp
# 2017-12-22 21:00:00+00:00  2017-12-22 14:31:00+00:00
# 2017-12-26 21:00:00+00:00  2017-12-26 14:31:00+00:00
# 2017-12-27 21:00:00+00:00  2017-12-27 14:31:00+00:00
# 2017-12-28 21:00:00+00:00  2017-12-28 14:31:00+00:00
# 2017-12-29 21:00:00+00:00  2017-12-29 14:31:00+00:00
#
#                                         period_close  portfolio_value  \
# timestamp
# 2017-12-22 21:00:00+00:00  2017-12-22 21:00:00+00:00     1.030901e+07
# 2017-12-26 21:00:00+00:00  2017-12-26 21:00:00+00:00     1.029969e+07
# 2017-12-27 21:00:00+00:00  2017-12-27 21:00:00+00:00     1.029975e+07
# ...

# %%
# Let us drop the unnamed column
df.drop(['Unnamed: 0', 'timestamp'], inplace  = True, axis = 1)

# %%
df.head()
# Out:
#                                          period_open  \
# timestamp
# 2008-01-02 21:00:00+00:00  2008-01-02 14:31:00+00:00
# 2008-01-03 21:00:00+00:00  2008-01-03 14:31:00+00:00
# 2008-01-04 21:00:00+00:00  2008-01-04 14:31:00+00:00
# 2008-01-07 21:00:00+00:00  2008-01-07 14:31:00+00:00
# 2008-01-08 21:00:00+00:00  2008-01-08 14:31:00+00:00
#
#                                         period_close  portfolio_value  \
# timestamp
# 2008-01-02 21:00:00+00:00  2008-01-02 21:00:00+00:00     1.000000e+07
# 2008-01-03 21:00:00+00:00  2008-01-03 21:00:00+00:00     9.999970e+06
# 2008-01-04 21:00:00+00:00  2008-01-04 21:00:00+00:00     9.995506e+06
# 2008-01-07 21:00:00+00:00  2008-01-07 21:00:00+00:00     9.994783e+06
# 2008-01-08 21:00:00+00:00  2008-01-08 21:00:00+00:00     9.992866e+06
#
#                            longs_count  shorts_count  long_value  short_value  \
# timestamp
# 2008-01-02 21:00:00+00:00            0             0         0.0          0.0
# ...

# %% [markdown]
# <b>Let us plot the volatility</b>

# %%
df.long_exposure.plot(figsize = (10,8))
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
def calculate_volatility(daily_returns):
    return np.std(daily_returns, ddof = 1) * math.sqrt(self.num_trading_days)

# %%
import numpy as np

A = np.random.normal(loc = 0, scale = 0.01, size = (100000,))
B = np.random.normal(loc = 0, scale = 0.99, size = (100000, ))

import matplotlib.pyplot as plt

fig = plt.figure(figsize = (16, 4))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
ax1.hist(A, density = True)
ax2.hist(B, density = True)
ax1.grid()
ax2.grid()
plt.show()

# %%
df.head()
# Out:
#                                          period_open  \
# timestamp
# 2008-01-02 21:00:00+00:00  2008-01-02 14:31:00+00:00
# 2008-01-03 21:00:00+00:00  2008-01-03 14:31:00+00:00
# 2008-01-04 21:00:00+00:00  2008-01-04 14:31:00+00:00
# 2008-01-07 21:00:00+00:00  2008-01-07 14:31:00+00:00
# 2008-01-08 21:00:00+00:00  2008-01-08 14:31:00+00:00
#
#                                         period_close  portfolio_value  \
# timestamp
# 2008-01-02 21:00:00+00:00  2008-01-02 21:00:00+00:00     1.000000e+07
# 2008-01-03 21:00:00+00:00  2008-01-03 21:00:00+00:00     9.999970e+06
# 2008-01-04 21:00:00+00:00  2008-01-04 21:00:00+00:00     9.995506e+06
# 2008-01-07 21:00:00+00:00  2008-01-07 21:00:00+00:00     9.994783e+06
# 2008-01-08 21:00:00+00:00  2008-01-08 21:00:00+00:00     9.992866e+06
#
#                            longs_count  shorts_count  long_value  short_value  \
# timestamp
# 2008-01-02 21:00:00+00:00            0             0         0.0          0.0
# ...

# %%
df.columns
# Out:
# Index(['period_open', 'period_close', 'portfolio_value', 'longs_count',
#        'shorts_count', 'long_value', 'short_value', 'long_exposure', 'pnl',
#        'short_exposure', 'capital_used', 'orders', 'transactions',
#        'gross_leverage', 'positions', 'net_leverage', 'starting_exposure',
#        'returns', 'ending_exposure', 'starting_value', 'ending_value',
#        'starting_cash', 'ending_cash', 'AAPI', 'algo_volatility',
#        'benchmark_period_return', 'benchmark_volatility',
#        'algorithm_period_return', 'alpha', 'beta', 'sharpe', 'sortino',
#        'max_drawdown', 'max_leverage', 'excess_return',
#        'treasury_period_return', 'trading_days', 'period_label'],
#       dtype='object')

# %%
# Alpha values comapre the portfolio and the market
df.alpha.plot(figsize = (16, 8))
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
df['alpha'].count()
# Out:
# 0

# %%
df.beta.plot(figsize = (16, 8))
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
df.algorithm_period_return.plot(figsize = (16, 8))
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
# Find the amount invested and the porfolio value
'${:,.2f}'.format(df.capital_used.sum())
# Out:
# '$-58,508.54'

# %%
'${:,.2f}'.format(df.portfolio_value[-1])
# Out:
# '$10,296,874.46'

# %%
# Net profit
'${:,.2f}'.format(df.portfolio_value[-1] + df.capital_used.sum())
# Out:
# '$10,238,365.92'

# %%
df.AAPI.plot(figsize = (16, 5))
# Out:
# <AxesSubplot:xlabel='timestamp'>
