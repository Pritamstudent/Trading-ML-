# %%
import pandas as pd

# %%
df = pd.read_csv('buy_and_hold.csv')
df.head()
# Out:
#                   Unnamed: 0                period_open  \
# 0  2017-01-03 21:00:00+00:00  2017-01-03 14:31:00+00:00
# 1  2017-01-04 21:00:00+00:00  2017-01-04 14:31:00+00:00
# 2  2017-01-05 21:00:00+00:00  2017-01-05 14:31:00+00:00
# 3  2017-01-06 21:00:00+00:00  2017-01-06 14:31:00+00:00
# 4  2017-01-09 21:00:00+00:00  2017-01-09 14:31:00+00:00
#
#                 period_close  shorts_count  long_value  short_value  \
# 0  2017-01-03 21:00:00+00:00             0         0.0          0.0
# 1  2017-01-04 21:00:00+00:00             0    405310.0          0.0
# 2  2017-01-05 21:00:00+00:00             0    811320.0          0.0
# 3  2017-01-06 21:00:00+00:00             0   1229280.0          0.0
# 4  2017-01-09 21:00:00+00:00             0   1651640.0          0.0
#
#    long_exposure       pnl  short_exposure  capital_used  ... alpha beta  \
# 0            0.0     0.000             0.0         0.000  ...   NaN  NaN
# 1       405310.0  -205.655             0.0   -405515.655  ...   NaN  NaN
# 2       811320.0   144.170             0.0   -405865.830  ...   NaN  NaN
# 3      1229280.0  7992.120             0.0   -409967.880  ...   NaN  NaN
# 4      1651640.0  9240.545             0.0   -413119.455  ...   NaN  NaN
#
#       sharpe     sortino  max_drawdown  max_leverage  excess_return  \
# 0        NaN         NaN      0.000000      0.000000            0.0
# 1 -11.224972  -11.224972     -0.000021      0.040532            0.0
# 2  -1.850455   -2.739988     -0.000021      0.081132            0.0
# 3   7.851011  306.084838     -0.000021      0.122831            0.0
# 4  11.471074  592.505264     -0.000021      0.164881            0.0
#
#    treasury_period_return  trading_days  period_label
# 0                     0.0             1       2017-01
# 1                     0.0             2       2017-01
# 2                     0.0             3       2017-01
# 3                     0.0             4       2017-01
# 4                     0.0             5       2017-01
#
# [5 rows x 39 columns]

# %%
df.tail()
# Out:
#                     Unnamed: 0                period_open  \
# 246  2017-12-22 21:00:00+00:00  2017-12-22 14:31:00+00:00
# 247  2017-12-26 21:00:00+00:00  2017-12-26 14:31:00+00:00
# 248  2017-12-27 21:00:00+00:00  2017-12-27 14:31:00+00:00
# 249  2017-12-28 21:00:00+00:00  2017-12-28 14:31:00+00:00
# 250  2017-12-29 21:00:00+00:00  2017-12-29 14:31:00+00:00
#
#                   period_close  shorts_count  long_value  short_value  \
# 246  2017-12-22 21:00:00+00:00             0  94758540.0          0.0
# 247  2017-12-26 21:00:00+00:00             0  93469780.0          0.0
# 248  2017-12-27 21:00:00+00:00             0  93527920.0          0.0
# 249  2017-12-28 21:00:00+00:00             0  94607280.0          0.0
# 250  2017-12-29 21:00:00+00:00             0  94272160.0          0.0
#
#      long_exposure          pnl  short_exposure  capital_used  ... alpha beta  \
# 246     94758540.0  -663225.860             0.0   -586015.860  ...   NaN  NaN
# 247     93469780.0 -1862309.630             0.0   -573549.630  ...   NaN  NaN
# 248     93527920.0  -510096.975             0.0   -568236.975  ...   NaN  NaN
# 249     94607280.0   506910.920             0.0   -572449.080  ...   NaN  NaN
# 250     94272160.0  -901526.060             0.0   -566406.060  ...   NaN  NaN
#
#        sharpe   sortino  max_drawdown  max_leverage  excess_return  \
# 246  1.321995  1.915393     -0.420485      5.422006            0.0
# 247  1.179045  1.694323     -0.420485      5.422006            0.0
# 248  1.136829  1.632669     -0.420485      5.422006            0.0
# 249  1.173407  1.686210     -0.420485      5.422006            0.0
# 250  1.099978  1.577329     -0.420485      5.514438            0.0
#
#      treasury_period_return  trading_days  period_label
# 246                     0.0           247       2017-12
# 247                     0.0           248       2017-12
# 248                     0.0           249       2017-12
# 249                     0.0           250       2017-12
# 250                     0.0           251       2017-12
#
# [5 rows x 39 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'period_open', 'period_close', 'shorts_count',
#        'long_value', 'short_value', 'long_exposure', 'pnl', 'short_exposure',
#        'capital_used', 'orders', 'transactions', 'gross_leverage', 'positions',
#        'net_leverage', 'starting_exposure', 'returns', 'ending_exposure',
#        'starting_value', 'ending_value', 'starting_cash', 'ending_cash',
#        'portfolio_value', 'longs_count', 'AAPI', 'algo_volatility',
#        'benchmark_period_return', 'benchmark_volatility',
#        'algorithm_period_return', 'alpha', 'beta', 'sharpe', 'sortino',
#        'max_drawdown', 'max_leverage', 'excess_return',
#        'treasury_period_return', 'trading_days', 'period_label'],
#       dtype='object')

# %%
# Change the index to the timestamp
df['timestamp'] = df['Unnamed: 0']
df.index = df.timestamp
df = df.drop(['timestamp', 'Unnamed: 0'], axis = 1)

# %%
df.head()
# Out:
#                                          period_open  \
# timestamp
# 2017-01-03 21:00:00+00:00  2017-01-03 14:31:00+00:00
# 2017-01-04 21:00:00+00:00  2017-01-04 14:31:00+00:00
# 2017-01-05 21:00:00+00:00  2017-01-05 14:31:00+00:00
# 2017-01-06 21:00:00+00:00  2017-01-06 14:31:00+00:00
# 2017-01-09 21:00:00+00:00  2017-01-09 14:31:00+00:00
#
#                                         period_close  shorts_count  \
# timestamp
# 2017-01-03 21:00:00+00:00  2017-01-03 21:00:00+00:00             0
# 2017-01-04 21:00:00+00:00  2017-01-04 21:00:00+00:00             0
# 2017-01-05 21:00:00+00:00  2017-01-05 21:00:00+00:00             0
# 2017-01-06 21:00:00+00:00  2017-01-06 21:00:00+00:00             0
# 2017-01-09 21:00:00+00:00  2017-01-09 21:00:00+00:00             0
#
#                            long_value  short_value  long_exposure       pnl  \
# timestamp
# 2017-01-03 21:00:00+00:00         0.0          0.0            0.0     0.000
# 2017-01-04 21:00:00+00:00    405310.0          0.0       405310.0  -205.655
# 2017-01-05 21:00:00+00:00    811320.0          0.0       811320.0   144.170
# 2017-01-06 21:00:00+00:00   1229280.0          0.0      1229280.0  7992.120
# 2017-01-09 21:00:00+00:00   1651640.0          0.0      1651640.0  9240.545
#
#                            short_exposure  capital_used  \
# timestamp
# 2017-01-03 21:00:00+00:00             0.0         0.000
# 2017-01-04 21:00:00+00:00             0.0   -405515.655
# 2017-01-05 21:00:00+00:00             0.0   -405865.830
# 2017-01-06 21:00:00+00:00             0.0   -409967.880
# 2017-01-09 21:00:00+00:00             0.0   -413119.455
#
#                                                                       orders  \
# timestamp
# 2017-01-03 21:00:00+00:00  [{'id': 'ef93710080e54d5b8da7b013e15fdf07', 'd...
# 2017-01-04 21:00:00+00:00  [{'id': 'ef93710080e54d5b8da7b013e15fdf07', 'd...
# 2017-01-05 21:00:00+00:00  [{'id': 'f93b172e3f55465993bd22335aaa528e', 'd...
# 2017-01-06 21:00:00+00:00  [{'id': '8b475846036e4c10a8a860ba43b39ab2', 'd...
# 2017-01-09 21:00:00+00:00  [{'id': '7a309ca90e9b450ab71d61fe9c6a3fc5', 'd...
#
#                            ... alpha  beta     sharpe     sortino  \
# timestamp                  ...
# 2017-01-03 21:00:00+00:00  ...   NaN   NaN        NaN         NaN
# 2017-01-04 21:00:00+00:00  ...   NaN   NaN -11.224972  -11.224972
# 2017-01-05 21:00:00+00:00  ...   NaN   NaN  -1.850455   -2.739988
# 2017-01-06 21:00:00+00:00  ...   NaN   NaN   7.851011  306.084838
# 2017-01-09 21:00:00+00:00  ...   NaN   NaN  11.471074  592.505264
#
#                            max_drawdown  max_leverage  excess_return  \
# timestamp
# 2017-01-03 21:00:00+00:00      0.000000      0.000000            0.0
# 2017-01-04 21:00:00+00:00     -0.000021      0.040532            0.0
# 2017-01-05 21:00:00+00:00     -0.000021      0.081132            0.0
# 2017-01-06 21:00:00+00:00     -0.000021      0.122831            0.0
# 2017-01-09 21:00:00+00:00     -0.000021      0.164881            0.0
#
#                            treasury_period_return  trading_days  period_label
# timestamp
# 2017-01-03 21:00:00+00:00                     0.0             1       2017-01
# 2017-01-04 21:00:00+00:00                     0.0             2       2017-01
# 2017-01-05 21:00:00+00:00                     0.0             3       2017-01
# 2017-01-06 21:00:00+00:00                     0.0             4       2017-01
# 2017-01-09 21:00:00+00:00                     0.0             5       2017-01
#
# [5 rows x 38 columns]

# %%
# Plot the time series data
from matplotlib import pyplot as plt
from matplotlib.dates import MonthLocator, date2num, DateFormatter

df.index = pd.DatetimeIndex(df.index)

fig, ax = plt.subplots()

fig.subplots_adjust(bottom = 0.3)

fig.set_figwidth(16)
fig.set_figheight(8)

ax.plot(df.index, df.algo_volatility)
ax.plot(df.index, df.benchmark_volatility)

lctr = MonthLocator()
frmt = DateFormatter('%b')

ax.xaxis.set_major_locator(lctr)
ax.xaxis.set_major_formatter(frmt)

plt.xticks(rotation = 70)
plt.tight_layout()

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Now let us see the profit
fig, ax = plt.subplots()

fig.subplots_adjust(bottom = 0.8)

fig.set_figwidth(16)
fig.set_figwidth(8)

ax.plot(df.index, df.algorithm_period_return)
ax.plot(df.index, df.benchmark_period_return)

lctr = MonthLocator()
frmt = DateFormatter('%b')

ax.xaxis.set_major_locator(lctr)
ax.xaxis.set_major_formatter(frmt)

plt.xticks(rotation = 70)
plt.tight_layout()

plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
print(df['benchmark_period_return'])
# Out:
# timestamp
# 2017-01-03 21:00:00+00:00    0.0
# 2017-01-04 21:00:00+00:00    0.0
# 2017-01-05 21:00:00+00:00    0.0
# 2017-01-06 21:00:00+00:00    0.0
# 2017-01-09 21:00:00+00:00    0.0
#                             ...
# 2017-12-22 21:00:00+00:00    0.0
# 2017-12-26 21:00:00+00:00    0.0
# 2017-12-27 21:00:00+00:00    0.0
# 2017-12-28 21:00:00+00:00    0.0
# 2017-12-29 21:00:00+00:00    0.0
# Name: benchmark_period_return, Length: 251, dtype: float64

# %%
# Now let us see the porfolio value
df.portfolio_value.plot(figsize = (16, 8))
# Out:
# <Axes: xlabel='timestamp'>

# %%
# Let us print the values
# Amount of the capital used
'${:,.2f}'.format(df.capital_used.sum())
# Out:
# '$-87,176,646.02'

# %%
# Print the protfolio values
'${:,.2f}'.format(df.portfolio_value[-1])
# Out:
# '$17,095,513.98'
